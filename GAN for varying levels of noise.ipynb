# %%
import numpy as np
import matplotlib.pyplot as plt 
from keras.layers import Conv2D, Input, Dense, Dropout, MaxPool2D, UpSampling2D
from keras.models import Model
from keras.datasets import mnist, cifar10

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
(cifar_train, _), (cifar_test, _) = cifar10.load_data()

size = 32
channel = 3
# scaling input data
cifar_train = cifar_train / 255
cifar_test = cifar_test / 255

# Adding noise mean = 0, std = 0.3
noise = 0.3
cifar_train_noise = cifar_train + noise * np.random.normal(0, 0.3, size=cifar_train.shape) 
cifar_test_noise = cifar_test + noise * np.random.normal(0, 0.3, size=cifar_test.shape)

cifar_train_noise = np.clip(cifar_train_noise, 0, 1)
cifar_test_noise = np.clip(cifar_test_noise, 0, 1)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 13s 0us/step

# %%
rows = 2 
cols = 8 

f = plt.figure(figsize=(2*cols,2*rows*2)) 

for i in range(rows):
    for j in range(cols): 
        f.add_subplot(rows*2,cols, (2*i*cols)+(j+1)) 
        plt.imshow(cifar_train_noise[i*cols + j]) 
        plt.axis("off")
        
    for j in range(cols): 
        f.add_subplot(rows*2,cols,((2*i+1)*cols)+(j+1)) 
        plt.imshow(cifar_train[i*cols + j]) 
        plt.axis("off")
        
f.suptitle("Sample Training Data",fontsize=18)
plt.savefig("/content/drive/My Drive/DAE/Cifar-trian.png")

plt.show()

# %%
from keras.layers import Conv2DTranspose, BatchNormalization, add, LeakyReLU
from keras.optimizers import Adam

# %%
# Encoder 
inputs = Input(shape=(size,size,channel))

x = Conv2D(32, 3, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)
x = MaxPool2D()(x)
x = Dropout(0.5)(x)
skip = Conv2D(32, 3, padding='same')(x) # skip connection for decoder
x = LeakyReLU()(skip)
x = BatchNormalization()(x)
x = MaxPool2D()(x)
x = Dropout(0.5)(x)
x = Conv2D(64, 3, activation='relu', padding='same')(x)
x = BatchNormalization()(x)
encoded = MaxPool2D()(x)

# Decoder
x = Conv2DTranspose(64, 3,activation='relu',strides=(2,2), padding='same')(encoded)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Conv2DTranspose(32, 3, activation='relu',strides=(2,2), padding='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Conv2DTranspose(32, 3, padding='same')(x)
x = add([x,skip]) # adding skip connection
x = LeakyReLU()(x)
x = BatchNormalization()(x)
decoded = Conv2DTranspose(3, 3, activation='sigmoid',strides=(2,2), padding='same')(x)

autoencoder = Model(inputs, decoded)
autoencoder.compile(optimizer=Adam(lr=0.001), loss='binary_crossentropy')
autoencoder.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 16, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 32)   9248        dropout[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 16, 16, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 32)   128         leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 32)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 8, 32)     0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 8, 64)     18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 8, 64)     256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 64)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 64)     36928       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 8, 64)     256         conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 64)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 32)   18464       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 32)   128         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 16, 16, 32)   9248        dropout_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 32)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 16, 16, 32)   0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 32)   128         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 3)    867         batch_normalization_5[0][0]
# ==================================================================================================
# Total params: 95,171
# Trainable params: 94,659
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
saveDir = "/content/drive/My Drive/DAE/"
chkpt = saveDir + 'Cifar10_denoise_weights.{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5'
cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

# %%
epochs = 100
batch_size = 256

history = autoencoder.fit(cifar_train_noise,
                cifar_train,
                epochs=epochs,
                batch_size=batch_size,
                callbacks=[cp_cb],
                shuffle=True,
                validation_data=(cifar_test_noise, cifar_test)
               )
# Out:
# Epoch 1/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5599
# Epoch 00001: val_loss improved from 0.57863 to 0.56079, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.01-0.56-0.56.hdf5
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5600 - val_loss: 0.5608
# Epoch 2/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5591
# Epoch 00002: val_loss improved from 0.56079 to 0.55934, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.02-0.56-0.56.hdf5
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5591 - val_loss: 0.5593
# Epoch 3/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5585
# Epoch 00003: val_loss did not improve from 0.55934
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5586 - val_loss: 0.5595
# Epoch 4/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5581
# Epoch 00004: val_loss improved from 0.55934 to 0.55665, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.04-0.56-0.56.hdf5
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5581 - val_loss: 0.5566
# Epoch 5/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5579
# Epoch 00005: val_loss improved from 0.55665 to 0.55600, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.05-0.56-0.56.hdf5
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5579 - val_loss: 0.5560
# Epoch 6/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5577
# Epoch 00006: val_loss improved from 0.55600 to 0.55585, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.06-0.56-0.56.hdf5
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5577 - val_loss: 0.5558
# Epoch 7/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5575
# Epoch 00007: val_loss improved from 0.55585 to 0.55553, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.07-0.56-0.56.hdf5
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5575 - val_loss: 0.5555
# Epoch 8/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5574
# Epoch 00008: val_loss improved from 0.55553 to 0.55544, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.08-0.56-0.56.hdf5
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5574 - val_loss: 0.5554
# Epoch 9/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5573
# Epoch 00009: val_loss did not improve from 0.55544
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5572 - val_loss: 0.5556
# Epoch 10/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5571
# Epoch 00010: val_loss improved from 0.55544 to 0.55537, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.10-0.56-0.56.hdf5
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5571 - val_loss: 0.5554
# Epoch 11/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5570
# Epoch 00011: val_loss did not improve from 0.55537
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5570 - val_loss: 0.5560
# Epoch 12/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5570
# Epoch 00012: val_loss improved from 0.55537 to 0.55509, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.12-0.56-0.56.hdf5
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5570 - val_loss: 0.5551
# Epoch 13/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5569
# Epoch 00013: val_loss did not improve from 0.55509
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5569 - val_loss: 0.5554
# Epoch 14/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5568
# Epoch 00014: val_loss did not improve from 0.55509
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5568 - val_loss: 0.5554
# Epoch 15/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5568
# Epoch 00015: val_loss improved from 0.55509 to 0.55493, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.15-0.56-0.55.hdf5
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5567 - val_loss: 0.5549
# Epoch 16/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5567
# Epoch 00016: val_loss improved from 0.55493 to 0.55481, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.16-0.56-0.55.hdf5
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5567 - val_loss: 0.5548
# Epoch 17/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5566
# Epoch 00017: val_loss did not improve from 0.55481
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5566 - val_loss: 0.5560
# Epoch 18/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5566
# Epoch 00018: val_loss improved from 0.55481 to 0.55475, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.18-0.56-0.55.hdf5
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5566 - val_loss: 0.5547
# Epoch 19/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5566
# Epoch 00019: val_loss did not improve from 0.55475
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5566 - val_loss: 0.5552
# Epoch 20/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5565
# Epoch 00020: val_loss did not improve from 0.55475
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5565 - val_loss: 0.5551
# Epoch 21/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5565
# Epoch 00021: val_loss did not improve from 0.55475
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5565 - val_loss: 0.5550
# Epoch 22/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5565
# Epoch 00022: val_loss did not improve from 0.55475
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5565 - val_loss: 0.5551
# Epoch 23/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5565
# Epoch 00023: val_loss did not improve from 0.55475
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5565 - val_loss: 0.5550
# Epoch 24/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5565
# Epoch 00024: val_loss did not improve from 0.55475
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5565 - val_loss: 0.5550
# Epoch 25/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5564
# Epoch 00025: val_loss did not improve from 0.55475
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5564 - val_loss: 0.5549
# Epoch 26/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5564
# Epoch 00026: val_loss did not improve from 0.55475
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5564 - val_loss: 0.5557
# Epoch 27/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5563
# Epoch 00027: val_loss did not improve from 0.55475
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5563 - val_loss: 0.5553
# Epoch 28/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5563
# Epoch 00028: val_loss did not improve from 0.55475
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5563 - val_loss: 0.5557
# Epoch 29/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5563
# Epoch 00029: val_loss did not improve from 0.55475
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5563 - val_loss: 0.5548
# Epoch 30/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5563
# Epoch 00030: val_loss did not improve from 0.55475
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5563 - val_loss: 0.5556
# Epoch 31/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5562
# Epoch 00031: val_loss did not improve from 0.55475
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5563 - val_loss: 0.5554
# Epoch 32/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5563
# Epoch 00032: val_loss improved from 0.55475 to 0.55464, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.32-0.56-0.55.hdf5
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5563 - val_loss: 0.5546
# Epoch 33/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5562
# Epoch 00033: val_loss did not improve from 0.55464
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5562 - val_loss: 0.5549
# Epoch 34/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5562
# Epoch 00034: val_loss did not improve from 0.55464
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5562 - val_loss: 0.5553
# Epoch 35/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5563
# Epoch 00035: val_loss improved from 0.55464 to 0.55458, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.35-0.56-0.55.hdf5
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5563 - val_loss: 0.5546
# Epoch 36/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5562
# Epoch 00036: val_loss improved from 0.55458 to 0.55442, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.36-0.56-0.55.hdf5
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5562 - val_loss: 0.5544
# Epoch 37/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5562
# Epoch 00037: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5562 - val_loss: 0.5551
# Epoch 38/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5562
# Epoch 00038: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5562 - val_loss: 0.5547
# Epoch 39/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5561
# Epoch 00039: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5561 - val_loss: 0.5549
# Epoch 40/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5562
# Epoch 00040: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5561 - val_loss: 0.5547
# Epoch 41/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5561
# Epoch 00041: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5561 - val_loss: 0.5555
# Epoch 42/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5561
# Epoch 00042: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5561 - val_loss: 0.5545
# Epoch 43/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5561
# Epoch 00043: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5561 - val_loss: 0.5555
# Epoch 44/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5560
# Epoch 00044: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5560 - val_loss: 0.5549
# Epoch 45/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5560
# Epoch 00045: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5560 - val_loss: 0.5546
# Epoch 46/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5561
# Epoch 00046: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5561 - val_loss: 0.5550
# Epoch 47/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5560
# Epoch 00047: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5561 - val_loss: 0.5550
# Epoch 48/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5560
# Epoch 00048: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5560 - val_loss: 0.5548
# Epoch 49/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5560
# Epoch 00049: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5560 - val_loss: 0.5551
# Epoch 50/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5560
# Epoch 00050: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5560 - val_loss: 0.5551
# Epoch 51/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5560
# Epoch 00051: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5560 - val_loss: 0.5550
# Epoch 52/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00052: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5560 - val_loss: 0.5553
# Epoch 53/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00053: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5560 - val_loss: 0.5557
# Epoch 54/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5560
# Epoch 00054: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5560 - val_loss: 0.5547
# Epoch 55/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00055: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5555
# Epoch 56/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00056: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5555
# Epoch 57/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00057: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5550
# Epoch 58/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00058: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5552
# Epoch 59/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00059: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5549
# Epoch 60/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5560
# Epoch 00060: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5546
# Epoch 61/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00061: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5554
# Epoch 62/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00062: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5550
# Epoch 63/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00063: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5563
# Epoch 64/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00064: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5554
# Epoch 65/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00065: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5548
# Epoch 66/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00066: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5545
# Epoch 67/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00067: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5553
# Epoch 68/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00068: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5546
# Epoch 69/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00069: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5550
# Epoch 70/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00070: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5545
# Epoch 71/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00071: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5546
# Epoch 72/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00072: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5547
# Epoch 73/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00073: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5559 - val_loss: 0.5548
# Epoch 74/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5559
# Epoch 00074: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5547
# Epoch 75/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00075: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5558 - val_loss: 0.5553
# Epoch 76/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00076: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5555
# Epoch 77/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00077: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5546
# Epoch 78/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00078: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5546
# Epoch 79/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00079: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5548
# Epoch 80/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00080: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5558 - val_loss: 0.5545
# Epoch 81/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00081: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5546
# Epoch 82/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00082: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5550
# Epoch 83/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00083: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5554
# Epoch 84/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5557
# Epoch 00084: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5553
# Epoch 85/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00085: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5550
# Epoch 86/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00086: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5545
# Epoch 87/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00087: val_loss did not improve from 0.55442
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5558 - val_loss: 0.5550
# Epoch 88/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00088: val_loss improved from 0.55442 to 0.55424, saving model to /content/drive/My Drive/DAE/Cifar10_denoise_weights.88-0.56-0.55.hdf5
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5558 - val_loss: 0.5542
# Epoch 89/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00089: val_loss did not improve from 0.55424
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5549
# Epoch 90/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00090: val_loss did not improve from 0.55424
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5548
# Epoch 91/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00091: val_loss did not improve from 0.55424
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5547
# Epoch 92/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00092: val_loss did not improve from 0.55424
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5548
# Epoch 93/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00093: val_loss did not improve from 0.55424
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5547
# Epoch 94/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00094: val_loss did not improve from 0.55424
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5552
# Epoch 95/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00095: val_loss did not improve from 0.55424
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5558 - val_loss: 0.5552
# Epoch 96/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00096: val_loss did not improve from 0.55424
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5549
# Epoch 97/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00097: val_loss did not improve from 0.55424
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5546
# Epoch 98/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00098: val_loss did not improve from 0.55424
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5547
# Epoch 99/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00099: val_loss did not improve from 0.55424
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5558 - val_loss: 0.5551
# Epoch 100/100
# 195/196 [============================>.] - ETA: 0s - loss: 0.5557
# Epoch 00100: val_loss did not improve from 0.55424
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5557 - val_loss: 0.5560

# %%
# Defining Figure
f = plt.figure(figsize=(10,7))
f.add_subplot()

#Adding Subplot
plt.plot(history.epoch, history.history['loss'], label = "loss") # Loss curve for training set
plt.plot(history.epoch, history.history['val_loss'], label = "val_loss") # Loss curve for validation set

plt.title("Loss Curve",fontsize=18)
plt.xlabel("Epochs",fontsize=15)
plt.ylabel("Loss",fontsize=15)
plt.grid(alpha=0.3)
plt.legend()
plt.savefig("/content/drive/My Drive/DAE/Loss_curve_cifar10_X.png")
plt.show()

# %%
from keras.models import load_model
autoencoder = load_model('/content/drive/My Drive/DAE/Cifar10_denoise_weights.88-0.56-0.55.hdf5')
# Select few random test images
num_imgs = 48
rand = np.random.randint(1, cifar_test_noise.shape[0]-48) 
cifar_test_imgs = cifar_test[rand:rand+num_imgs]
cifar_test_images = cifar_test_noise[rand:rand+num_imgs] # slicing
cifar_test_desoided = autoencoder.predict(cifar_test_images) # predict

# %%
# Visualize test images with their denoised images

rows = 4 # defining no. of rows in figure
cols = 12 # defining no. of colums in figure
cell_size = 1.5
f = plt.figure(figsize=(cell_size*cols,cell_size*rows*2)) # defining a figure 
f.tight_layout()
for i in range(rows):
    for j in range(cols): 
        f.add_subplot(rows*3,cols, (3*i*cols)+(j+1)) # adding sub plot to figure on each iteration
        plt.imshow(cifar_test_imgs[i*cols + j]) 
        plt.axis("off")
        
    for j in range(cols): 
        f.add_subplot(rows*3,cols,((3*i+1)*cols)+(j+1)) # adding sub plot to figure on each iteration
        plt.imshow(cifar_test_images[i*cols + j]) 
        plt.axis("off")

    for j in range(cols):
        f.add_subplot(rows*3,cols,((3*i+2)*cols)+(j+1)) # adding sub plot to figure on each iteration
        plt.imshow(cifar_test_desoided[i*cols + j]) 
        plt.axis("off")

f.suptitle("Autoencoder Results - Cifar10",fontsize=18)
plt.savefig("/content/drive/My Drive/DAE/test_results_cifar10_X.png")

plt.show()

# %%
row = 5
for i in range(5):
  f = plt.figure(figsize=(1,1)) # defining a figure 
  f.tight_layout()
  #plt.subplots(frameon=False)
  #f.add_subplot(rows,cols, (i*cols)+(j+1)) # adding sub plot to figure on each iteration
  plt.imshow(cifar_test_imgs[i]) 
  plt.axis("off")
  plt.savefig("/content/drive/My Drive/DAE/input_cifar10_%i.png"%i, bbox_inches='tight', pad_inches=0)
  plt.show()

#f.suptitle("Autoencoder Results - Cifar10",fontsize=18)

# %%
row = 5
for i in range(5):
  f = plt.figure(figsize=(1,1)) # defining a figure 
  f.tight_layout()
  #plt.subplots(frameon=False)
  #f.add_subplot(rows,cols, (i*cols)+(j+1)) # adding sub plot to figure on each iteration
  plt.imshow(cifar_test_desoided[i]) 
  plt.axis("off")
  plt.savefig("/content/drive/My Drive/DAE/output_cifar10_%i.png"%i, bbox_inches='tight', pad_inches=0)
  plt.show()

# %%
# Visualize test images with their denoised images

rows = 3 # defining no. of rows in figure
cols = 3 # defining no. of colums in figure
cell_size = 1.5
f = plt.figure(figsize=(cell_size*cols,cell_size*rows)) # defining a figure 
f.tight_layout()
for i in range(rows):
    for j in range(cols): 
        f.add_subplot(rows,cols, (i*cols)+(j+1)) # adding sub plot to figure on each iteration
        plt.imshow(cifar_test_desoided[i*cols + j]) 
        plt.axis("off")

f.suptitle("Autoencoder Reconstructed - Cifar10",fontsize=18)
plt.savefig("/content/drive/My Drive/DAE/DAE_recon.png")
plt.show()
